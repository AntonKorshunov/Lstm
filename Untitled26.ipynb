# %%
import numpy as np

from tensorflow.keras.layers import Dense, SimpleRNN, Input, Embedding
from tensorflow.keras.models import Sequential
from tensorflow.keras.preprocessing.text import Tokenizer, text_to_word_sequence
from tensorflow.keras.utils import to_categorical

with open('123', 'r', encoding='utf-8') as f:
    texts = f.read()
    texts = texts.replace('\ufeff', '')  # убираем первый невидимый символ

maxWordsCount = 10000
tokenizer = Tokenizer(num_words=maxWordsCount, filters='!–"—#$%&amp;()*+,-./:;<=>?@[\\]^_`{|}~\t\n\r«»',
                      lower=True, split=' ', char_level=False)
tokenizer.fit_on_texts([texts])
data = tokenizer.texts_to_sequences([texts])
res = np.array( data[0] )

inp_words = 3
n = res.shape[0] - inp_words

X = np.array([res[i:i + inp_words] for i in range(n)])
Y = to_categorical(res[inp_words:], num_classes=maxWordsCount)

model = Sequential()
model.add(Embedding(maxWordsCount, 256, input_length = inp_words))
model.add(SimpleRNN(128, activation='tanh'))
model.add(Dense(maxWordsCount, activation='softmax'))
model.summary()

model.compile(loss='categorical_crossentropy', metrics=['accuracy'], optimizer='adam')

history = model.fit(X, Y, batch_size=64, epochs=50)
# Out:
# Model: "sequential_1"
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# =================================================================
# embedding_1 (Embedding)      (None, 3, 256)            2560000
# _________________________________________________________________
# simple_rnn_1 (SimpleRNN)     (None, 128)               49280
# _________________________________________________________________
# dense_1 (Dense)              (None, 10000)             1290000
# =================================================================
# Total params: 3,899,280
# Trainable params: 3,899,280
# Non-trainable params: 0
# _________________________________________________________________
# Epoch 1/50
# 413/413 [==============================] - 26s 64ms/step - loss: 8.4389 - accuracy: 0.0230
# Epoch 2/50
# 413/413 [==============================] - 26s 64ms/step - loss: 7.6073 - accuracy: 0.0308
# Epoch 3/50
# 413/413 [==============================] - 27s 64ms/step - loss: 6.9459 - accuracy: 0.0395
# Epoch 4/50
# 413/413 [==============================] - 25s 61ms/step - loss: 6.1588 - accuracy: 0.0702
# Epoch 5/50
# 413/413 [==============================] - 27s 66ms/step - loss: 5.2444 - accuracy: 0.1483
# Epoch 6/50
# 413/413 [==============================] - 26s 64ms/step - loss: 4.3181 - accuracy: 0.2948
# Epoch 7/50
# 413/413 [==============================] - 30s 72ms/step - loss: 3.4513 - accuracy: 0.4697
# Epoch 8/50
# 413/413 [==============================] - 31s 76ms/step - loss: 2.6709 - accuracy: 0.6186
# Epoch 9/50
# 413/413 [==============================] - 30s 74ms/step - loss: 2.0030 - accuracy: 0.7239
# Epoch 10/50
# 413/413 [==============================] - 30s 73ms/step - loss: 1.4700 - accuracy: 0.8002
# Epoch 11/50
# 413/413 [==============================] - 30s 72ms/step - loss: 1.0764 - accuracy: 0.8539
# Epoch 12/50
# 413/413 [==============================] - 31s 75ms/step - loss: 0.8014 - accuracy: 0.8898
# Epoch 13/50
# 413/413 [==============================] - 31s 74ms/step - loss: 0.6044 - accuracy: 0.9160
# Epoch 14/50
# 413/413 [==============================] - 31s 75ms/step - loss: 0.4645 - accuracy: 0.9348
# Epoch 15/50
# 413/413 [==============================] - 31s 74ms/step - loss: 0.3604 - accuracy: 0.9495
# Epoch 16/50
# 413/413 [==============================] - 32s 76ms/step - loss: 0.2855 - accuracy: 0.9587
# Epoch 17/50
# 413/413 [==============================] - 29s 70ms/step - loss: 0.2257 - accuracy: 0.9673
# Epoch 18/50
# 413/413 [==============================] - 31s 75ms/step - loss: 0.1806 - accuracy: 0.9739
# Epoch 19/50
# 413/413 [==============================] - 32s 78ms/step - loss: 0.1493 - accuracy: 0.9765
# Epoch 20/50
# 413/413 [==============================] - 29s 71ms/step - loss: 0.1222 - accuracy: 0.9804
# Epoch 21/50
# 413/413 [==============================] - 32s 77ms/step - loss: 0.1029 - accuracy: 0.9825
# Epoch 22/50
# 413/413 [==============================] - 33s 79ms/step - loss: 0.0868 - accuracy: 0.9840
# Epoch 23/50
# 413/413 [==============================] - 30s 73ms/step - loss: 0.0769 - accuracy: 0.9848
# Epoch 24/50
# 413/413 [==============================] - 31s 76ms/step - loss: 0.0672 - accuracy: 0.9858
# Epoch 25/50
# 413/413 [==============================] - 32s 78ms/step - loss: 0.0606 - accuracy: 0.9858
# Epoch 26/50
# 413/413 [==============================] - 29s 70ms/step - loss: 0.0573 - accuracy: 0.9862
# Epoch 27/50
# 413/413 [==============================] - 31s 75ms/step - loss: 0.0520 - accuracy: 0.9864
# Epoch 28/50
# 413/413 [==============================] - 33s 80ms/step - loss: 0.0493 - accuracy: 0.9867
# Epoch 29/50
# 413/413 [==============================] - 33s 80ms/step - loss: 0.0458 - accuracy: 0.9870
# Epoch 30/50
# 413/413 [==============================] - 33s 79ms/step - loss: 0.0449 - accuracy: 0.9862
# Epoch 31/50
# 413/413 [==============================] - 32s 76ms/step - loss: 0.0436 - accuracy: 0.9866
# Epoch 32/50
# 413/413 [==============================] - 32s 77ms/step - loss: 0.0411 - accuracy: 0.9870
# Epoch 33/50
# 413/413 [==============================] - 32s 77ms/step - loss: 0.0404 - accuracy: 0.9866
# Epoch 34/50
# 413/413 [==============================] - 31s 75ms/step - loss: 0.0413 - accuracy: 0.9858
# Epoch 35/50
# 413/413 [==============================] - 31s 75ms/step - loss: 0.0401 - accuracy: 0.9861
# Epoch 36/50
# 413/413 [==============================] - 33s 79ms/step - loss: 0.0384 - accuracy: 0.9864
# Epoch 37/50
# 413/413 [==============================] - 34s 81ms/step - loss: 0.0372 - accuracy: 0.9866
# Epoch 38/50
# 413/413 [==============================] - 32s 77ms/step - loss: 0.0355 - accuracy: 0.9867
# Epoch 39/50
# 413/413 [==============================] - 31s 75ms/step - loss: 0.0351 - accuracy: 0.9867
# Epoch 40/50
# 413/413 [==============================] - 31s 76ms/step - loss: 0.0339 - accuracy: 0.9871
# Epoch 41/50
# 413/413 [==============================] - 31s 75ms/step - loss: 0.0333 - accuracy: 0.9868
# Epoch 42/50
# 413/413 [==============================] - 31s 75ms/step - loss: 0.0333 - accuracy: 0.9864
# Epoch 43/50
# 413/413 [==============================] - 33s 79ms/step - loss: 0.0321 - accuracy: 0.9873
# Epoch 44/50
# 413/413 [==============================] - 30s 73ms/step - loss: 0.0330 - accuracy: 0.9869
# Epoch 45/50
# 413/413 [==============================] - 31s 76ms/step - loss: 0.0332 - accuracy: 0.9868
# Epoch 46/50
# 413/413 [==============================] - 32s 78ms/step - loss: 0.0346 - accuracy: 0.9864
# Epoch 47/50
# 413/413 [==============================] - 33s 79ms/step - loss: 0.0347 - accuracy: 0.9868
# Epoch 48/50
# 413/413 [==============================] - 31s 76ms/step - loss: 0.0329 - accuracy: 0.9862
# Epoch 49/50
# 413/413 [==============================] - 31s 76ms/step - loss: 0.0306 - accuracy: 0.9866
# Epoch 50/50
# 413/413 [==============================] - 30s 74ms/step - loss: 0.0303 - accuracy: 0.9863

# %%
def buildPhrase(texts, str_len=8):
    res = texts
    data = tokenizer.texts_to_sequences([texts])[0]
    for i in range(str_len):
        x = data[i: i + inp_words]
        inp = np.expand_dims(x, axis=0)
        pred = model.predict(inp)
        indx = pred.argmax(axis=1)[0]
        data.append(indx)

        res += " " + tokenizer.index_word[indx]  # дописываем строку

    return res

# %%
res = buildPhrase("несколько дней назад")
print(res)
# Out:
# несколько дней назад подстерегала его то около подъезда то на казанской
